# %% [markdown]
# ## 1. Giới thiệu về thư viện NLTK

# %%
# !pip install nltk -q

# %%
import nltk
nltk.download('gutenberg')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %%
gb = nltk.corpus.gutenberg
print("Gutenberg files : ", gb.fileids())
# Out:
# Gutenberg files :  ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
macbeth = nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')
len(macbeth)
# Out:
# 23140

# %%
macbeth[:10]
# Out:
# ['[',
#  'The',
#  'Tragedie',
#  'of',
#  'Macbeth',
#  'by',
#  'William',
#  'Shakespeare',
#  '1603',
#  ']']

# %%
macbeth_sents = nltk.corpus.gutenberg.sents('shakespeare-macbeth.txt')
macbeth_sents[:5]
# Out:
# [['[',
#   'The',
#   'Tragedie',
#   'of',
#   'Macbeth',
#   'by',
#   'William',
#   'Shakespeare',
#   '1603',
#   ']'],
#  ['Actus', 'Primus', '.'],
#  ['Scoena', 'Prima', '.'],
#  ['Thunder', 'and', 'Lightning', '.'],
#  ['Enter', 'three', 'Witches', '.']]

# %% [markdown]
# ## 2. Tìm 1 từ với NLTK

# %%
text = nltk.Text(macbeth)
text.concordance('Stage')
# Out:
# Displaying 3 of 3 matches:
# nts with Dishes and Seruice ouer the Stage . Then enter Macbeth Macb . If it we
# with mans Act , Threatens his bloody Stage : byth ' Clock ' tis Day , And yet d
#  struts and frets his houre vpon the Stage , And then is heard no more . It is

# %%
text.common_contexts(['Stage'])
# Out:
# the_. bloody_: the_,

# %%
text.similar('Stage')
# Out:
# day time face warre ayre king bleeding man reuolt serieant like
# knowledge broyle shew head spring heeles hare thane skie

# %% [markdown]
# ## 3. Phân tích tần số của các từ

# %%
fd = nltk.FreqDist(macbeth)
fd.most_common(10)
# Out:
# [(',', 1962),
#  ('.', 1235),
#  ("'", 637),
#  ('the', 531),
#  (':', 477),
#  ('and', 376),
#  ('I', 333),
#  ('of', 315),
#  ('to', 311),
#  ('?', 241)]

# %%
sw = set(nltk.corpus.stopwords.words('english'))
print(len(sw))
list(sw)[:10]
# Out:
# 198
# ['yourself',
#  "they've",
#  "we've",
#  'after',
#  'any',
#  'then',
#  'as',
#  'down',
#  'that',
#  'just']

# %%
macbeth_filtered = [w for w in macbeth if w.lower() not in sw]
len(macbeth_filtered)
# Out:
# 14946

# %%
fd = nltk.FreqDist(macbeth_filtered)
fd.most_common(10)
# Out:
# [(',', 1962),
#  ('.', 1235),
#  ("'", 637),
#  (':', 477),
#  ('?', 241),
#  ('Macb', 137),
#  ('haue', 117),
#  ('-', 100),
#  ('Enter', 80),
#  ('thou', 63)]

# %%
import string
punctuation = set(string.punctuation)
macbeth_filtered2 = [w.lower() for w in macbeth if w.lower() not in sw and w.lower() not in punctuation]
fd = nltk.FreqDist(macbeth_filtered2)
fd.most_common(10)
# Out:
# [('macb', 137),
#  ('haue', 122),
#  ('thou', 90),
#  ('enter', 81),
#  ('shall', 68),
#  ('macbeth', 62),
#  ('vpon', 62),
#  ('thee', 61),
#  ('macd', 58),
#  ('vs', 57)]

# %% [markdown]
# ## 4. Lựa chọn các từ trong văn bản

# %%
long_words = [w for w in macbeth if len(w) > 12]
sorted(long_words)
# Out:
# ['Assassination',
#  'Chamberlaines',
#  'Distinguishes',
#  'Gallowgrosses',
#  'Metaphysicall',
#  'Northumberland',
#  'Voluptuousnesse',
#  'commendations',
#  'multitudinous',
#  'supernaturall',
#  'vnaccompanied']

# %%
ious_words = [w for w in macbeth if 'ious' in w]
ious_words = set(ious_words)
sorted(ious_words)
# Out:
# ['Auaricious',
#  'Gracious',
#  'Industrious',
#  'Iudicious',
#  'Luxurious',
#  'Malicious',
#  'Obliuious',
#  'Pious',
#  'Rebellious',
#  'compunctious',
#  'furious',
#  'gracious',
#  'pernicious',
#  'pernitious',
#  'pious',
#  'precious',
#  'rebellious',
#  'sacrilegious',
#  'serious',
#  'spacious',
#  'tedious']

# %% [markdown]
# ## 5. Bigrams và collocations

# %%
bgrms = nltk.FreqDist(nltk.bigrams(macbeth_filtered2))
bgrms.most_common(15)
# Out:
# [(('enter', 'macbeth'), 16),
#  (('exeunt', 'scena'), 15),
#  (('thane', 'cawdor'), 13),
#  (('knock', 'knock'), 10),
#  (('st', 'thou'), 9),
#  (('thou', 'art'), 9),
#  (('lord', 'macb'), 9),
#  (('haue', 'done'), 8),
#  (('macb', 'haue'), 8),
#  (('good', 'lord'), 8),
#  (('let', 'vs'), 7),
#  (('enter', 'lady'), 7),
#  (('wee', 'l'), 7),
#  (('would', 'st'), 6),
#  (('macbeth', 'macb'), 6)]

# %%
tgrms = nltk.FreqDist(nltk.trigrams(macbeth_filtered2))
tgrms.most_common(10)
# Out:
# [(('knock', 'knock', 'knock'), 6),
#  (('enter', 'macbeth', 'macb'), 5),
#  (('enter', 'three', 'witches'), 4),
#  (('exeunt', 'scena', 'secunda'), 4),
#  (('good', 'lord', 'macb'), 4),
#  (('three', 'witches', '1'), 3),
#  (('exeunt', 'scena', 'tertia'), 3),
#  (('thunder', 'enter', 'three'), 3),
#  (('exeunt', 'scena', 'quarta'), 3),
#  (('scena', 'prima', 'enter'), 3)]

# %% [markdown]
# ## 6. Sử dụng văn bản trên mạng

# %%
from urllib import request

url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)

raw = response.read().decode("utf-8-sig")
print(raw[:75])
# Out:
# *** START OF THE PROJECT GUTENBERG EBOOK 2554 ***
#
#
#
#
# CRIME AND PUNISHMENT

# %%
tokens = nltk.word_tokenize(raw)
webtext = nltk.Text(tokens)
webtext[:12]
# Out:
# ['*',
#  '*',
#  '*',
#  'START',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  '2554',
#  '*',
#  '*']

# %% [markdown]
# ## 7. Rút trích văn bản từ trang html

# %%
# !pip install beautifulsoup4 lxml -q

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = request.urlopen(url).read().decode('utf8')
html[:120]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">\r\n<html>\r\n<hea'

# %%
from bs4 import BeautifulSoup
raw = BeautifulSoup(html, "lxml").get_text()
tokens = nltk.word_tokenize(raw)
text = nltk.Text(tokens)
text[:20]
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  'years',
#  "'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX']

# %% [markdown]
# ## 8. Phân tích cảm xúc người dùng

# %%
import random
reviews = nltk.corpus.movie_reviews
documents = [(list(reviews.words(fileid)), category)
             for category in reviews.categories()
             for fileid in reviews.fileids(category)]
random.shuffle(documents)

# %%
first_review = ' '.join(documents[0][0])
print(first_review)
# Out:
# play it to the bone is a punch - drunk mess of a movie . containing a good cast but awful acting ; an interesting premise but terrible execution , ron shelton ( white men can ' t jump ) gives us a rocky story with not one rocky but two . rocky no . 1 is vince boudreau ( woody harrelson , edtv ) , a bald , tattooed , newly converted christian , whose idea of christianity is not using the name of christ as a curse word . . . something that he has not yet successfully achieved . rocky no . 2 is caesar dominguez ( antonio banderas , the 13th warrior ) , best friend of vince who is currently dating vince ' s ex - girlfriend , grace . both men are nearing the end of their " almost " careers when a fluke provides them with a redemptive opportunity . when both fighters of the undercard of a vegas based mike tyson title fight become incapacitated , the fight promoters need to find a quick replacement . our boys are tapped to fight each other , the winner of which is " promised " a shot at a f
# ...

# %%
documents[0][1]
# Out:
# 'neg'

# %%
all_words = nltk.FreqDist(w.lower() for w in reviews.words())
word_features = list(all_words)

# %%
def document_features(document, word_features):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['{}'.format(word)] = (word in document_words)
    return features

# %%
featuresets = [(document_features(d, word_features), c) for (d, c) in documents]
len(featuresets)
# Out:
# 2000

# %%
train_set, test_set = featuresets[1500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.76

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#                   poorly = True              neg : pos    =      9.2 : 1.0
#                  crafted = True              pos : neg    =      9.0 : 1.0
#            uninteresting = True              neg : pos    =      8.2 : 1.0
#               delightful = True              pos : neg    =      7.8 : 1.0
#                   driver = True              pos : neg    =      7.8 : 1.0
#            understanding = True              pos : neg    =      7.8 : 1.0
#                 strictly = True              neg : pos    =      7.5 : 1.0
#                    worst = True              neg : pos    =      7.5 : 1.0
#                 develops = True              pos : neg    =      7.1 : 1.0
#                filmmaker = True              pos : neg    =      7.1 : 1.0

# %% [markdown]
# ## 9. Bài tập áp dụng
#
# 1. Liệt kê các tên của corpus.
# 2. Liệt kê danh sách các stopword bằng các ngôn ngữ khác nhau.
# 3. Kiểm tra danh sách các stopword bằng các ngôn ngữ khác nhau.
# 4. Loại bỏ các stopword từ một văn bản đã cho.
# 5. Bỏ qua các stopword từ danh sách các stopword.
# 6. Tìm định nghĩa và ví dụ của một từ đã cho bằng WordNet.
# 7. Tìm tập hợp các từ đồng nghĩa và trái nghĩa của một từ nào đó.
# 8. Xem tổng quan bộ tag, chi tiết của một tag cụ thể và các bộ tag liên quan.
# 9. So sánh sự giống nhau của hai danh từ đã cho.
# 10. So sánh sự giống nhau của hai động từ đã cho.
# 11. Tìm số lượng tên nam và nữ trong kho ngữ liệu names, in 10 tên đầu mỗi loại.
# 12. In 15 kết hợp ngẫu nhiên đầu tiên được gắn nhãn nam/nữ từ kho tên.
# 13. Trích xuất ký tự cuối cùng của tất cả các tên được gắn nhãn, tạo mảng mới gồm chữ cái cuối và nhãn tương ứng.

# %%
# Bài 1
print(nltk.corpus.gutenberg.fileids())
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']

# %%
# Bài 2
nltk.download('stopwords')
print(nltk.corpus.stopwords.fileids())
# Out:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish', 'uzbek']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Bài 3
lang = 'english'
print(lang in nltk.corpus.stopwords.fileids())
# Out:
# True

# %%
# Bài 4
sample_text = "This is a sample text with some stopwords in it".split()
sw_en = set(nltk.corpus.stopwords.words('english'))
filtered = [w for w in sample_text if w.lower() not in sw_en]
print(filtered)
# Out:
# ['sample', 'text', 'stopwords']

# %%
# Bài 5
custom_ignore = {'this', 'is', 'a'}
sw_reduced = sw_en - custom_ignore
filtered2 = [w for w in sample_text if w.lower() not in sw_reduced]
print(filtered2)
# Out:
# ['This', 'is', 'a', 'sample', 'text', 'stopwords']

# %%
# Bài 6
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import wordnet
word = 'good'
for syn in wordnet.synsets(word)[:3]:
    print(syn.name(), '-', syn.definition())
    print('Ví dụ:', syn.examples())
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# good.n.01 - benefit
# Ví dụ: ['for your own good', "what's the good of worrying?"]
# good.n.02 - moral excellence or admirableness
# Ví dụ: ['there is much good to be found in people']
# good.n.03 - that which is pleasing or valuable or useful
# Ví dụ: ['weigh the good against the bad', 'among the highest goods of all are happiness and self-realization']

# %%
# Bài 7
synonyms, antonyms = [], []
for syn in wordnet.synsets('good'):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())
        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())
print("Đồng nghĩa:", set(synonyms))
print("Trái nghĩa:", set(antonyms))
# Out:
# Đồng nghĩa: {'soundly', 'full', 'salutary', 'secure', 'safe', 'just', 'honorable', 'effective', 'adept', 'goodness', 'commodity', 'honest', 'well', 'unspoilt', 'serious', 'trade_good', 'beneficial', 'in_effect', 'skilful', 'proficient', 'expert', 'in_force', 'practiced', 'upright', 'skillful', 'undecomposed', 'near', 'sound', 'estimable', 'dear', 'thoroughly', 'good', 'respectable', 'ripe', 'unspoiled', 'dependable', 'right'}
# Trái nghĩa: {'bad', 'evil', 'evilness', 'ill', 'badness'}

# %%
# Bài 8
import nltk

nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.
# True

# %%
# Bài 8 (tiếp) - chi tiết 1 tag cụ thể
nltk.help.upenn_tagset('NN')
# Out:
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...

# %%
# Bài 9
word1 = wordnet.synsets('car', pos=wordnet.NOUN)[0]
word2 = wordnet.synsets('automobile', pos=wordnet.NOUN)[0]
print(word1.wup_similarity(word2))
# Out:
# 1.0

# %%
# Bài 10
verb1 = wordnet.synsets('run', pos=wordnet.VERB)[0]
verb2 = wordnet.synsets('sprint', pos=wordnet.VERB)[0]
print(verb1.wup_similarity(verb2))
# Out:
# 0.8571428571428571

# %%
# Bài 11
nltk.download('names')
from nltk.corpus import names
males = names.words('male.txt')
females = names.words('female.txt')
print("Số tên nam:", len(males))
print("Số tên nữ:", len(females))
print("10 tên nam đầu tiên:", males[:10])
print("10 tên nữ đầu tiên:", females[:10])
# Out:
# Số tên nam: 2943
# Số tên nữ: 5001
# 10 tên nam đầu tiên: ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot', 'Abbott', 'Abby', 'Abdel', 'Abdul', 'Abdulkarim']
# 10 tên nữ đầu tiên: ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi', 'Abbie', 'Abby', 'Abigael', 'Abigail', 'Abigale']
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.

# %%
# Bài 12
labeled_names = ([(name, 'male') for name in males] +
                  [(name, 'female') for name in females])
random.shuffle(labeled_names)
print(labeled_names[:15])
# Out:
# [('Barret', 'male'), ('Simeon', 'male'), ('Wes', 'male'), ('Claresta', 'female'), ('Winnah', 'female'), ('Carlynn', 'female'), ('Doria', 'female'), ('Jenica', 'female'), ('Zabrina', 'female'), ('Zuzana', 'female'), ('Sashenka', 'female'), ('Merry', 'male'), ('Brett', 'female'), ('Roderic', 'male'), ('Jesselyn', 'female')]

# %%
# Bài 13
last_letters = [(name[-1], gender) for (name, gender) in labeled_names]
print(last_letters[:15])
# Out:
# [('t', 'male'), ('n', 'male'), ('s', 'male'), ('a', 'female'), ('h', 'female'), ('n', 'female'), ('a', 'female'), ('a', 'female'), ('a', 'female'), ('a', 'female'), ('a', 'female'), ('y', 'male'), ('t', 'female'), ('c', 'male'), ('n', 'female')]
